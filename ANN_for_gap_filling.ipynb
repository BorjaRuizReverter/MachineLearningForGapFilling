# %%
import pandas as pd
import numpy as np

df_uncleaned = pd.read_excel('PRE2013.xlsx')
df_uncleaned
# Out:
#        Day  Hour         NEE         LE         H        Rg      Tair  \
# 0       --    --  umolm-2s-1       Wm-2      Wm-2      Wm-2      degC
# 1        1   0.5       -9999      -9999     -9999     -9999     -9999
# 2        1     1       -9999      -9999     -9999     -9999     -9999
# 3        1   1.5       -9999      -9999     -9999     -9999     -9999
# 4        1     2       -9999      -9999     -9999     -9999     -9999
# ...    ...   ...         ...        ...       ...       ...       ...
# 17516  365    22    1.317576  -2.113446 -4.222929 -1.650576  24.11463
# 17517  365  22.5    0.234337 -17.096266  1.974016 -2.103711  23.99404
# 17518  365    23   -0.224384 -10.566178 -5.732129 -2.074909  23.87093
# 17519  365  23.5    1.597789  -9.588491 -4.534221 -2.309459   23.6706
# 17520  365    24    1.426377   -5.17779 -6.128092 -1.824817  23.67208
#
#           Tsoil        rH       VPD     Ustar
# 0          degC         %       hPa      ms-1
# 1         -9999     -9999     -9999     -9999
# 2         -9999     -9999     -9999     -9999
# 3         -9999     -9999     -9999     -9999
# 4         -9999     -9999     -9999     -9999
# ...         ...       ...       ...       ...
# 17516  29.31614  84.10452  4.693953  0.341839
# 17517  29.22911  86.27364  4.024035  0.374856
# 17518  29.14392  87.43149  3.657315  0.360931
# 17519  29.05899  88.96199  3.173296  0.431153
# 17520  28.97242  89.76054  2.943986  0.366103
#
# [17521 rows x 11 columns]

# %%
'''Doesnt substitute the df this way
#df.replace(-9999, np.nan)
'''
df_withNaN = df_uncleaned.replace(to_replace=-9999, value = np.nan)
df_withNaN
# Out:
#        Day  Hour         NEE         LE         H        Rg      Tair  \
# 0       --    --  umolm-2s-1       Wm-2      Wm-2      Wm-2      degC
# 1        1   0.5         NaN        NaN       NaN       NaN       NaN
# 2        1     1         NaN        NaN       NaN       NaN       NaN
# 3        1   1.5         NaN        NaN       NaN       NaN       NaN
# 4        1     2         NaN        NaN       NaN       NaN       NaN
# ...    ...   ...         ...        ...       ...       ...       ...
# 17516  365    22    1.317576  -2.113446 -4.222929 -1.650576  24.11463
# 17517  365  22.5    0.234337 -17.096266  1.974016 -2.103711  23.99404
# 17518  365    23   -0.224384 -10.566178 -5.732129 -2.074909  23.87093
# 17519  365  23.5    1.597789  -9.588491 -4.534221 -2.309459   23.6706
# 17520  365    24    1.426377   -5.17779 -6.128092 -1.824817  23.67208
#
#           Tsoil        rH       VPD     Ustar
# 0          degC         %       hPa      ms-1
# 1           NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN
# 3           NaN       NaN       NaN       NaN
# 4           NaN       NaN       NaN       NaN
# ...         ...       ...       ...       ...
# 17516  29.31614  84.10452  4.693953  0.341839
# 17517  29.22911  86.27364  4.024035  0.374856
# 17518  29.14392  87.43149  3.657315  0.360931
# 17519  29.05899  88.96199  3.173296  0.431153
# 17520  28.97242  89.76054  2.943986  0.366103
#
# [17521 rows x 11 columns]

# %%
'''
It also doesnt work unless I assign the result to a new one df
'''
df_withoutNaN = df_withNaN.dropna().reset_index(drop=True)
df_withoutNaN
# Out:
#        Day  Hour         NEE         LE         H        Rg      Tair  \
# 0       --    --  umolm-2s-1       Wm-2      Wm-2      Wm-2      degC
# 1        8   9.5   -1.282251  19.633976  293.5131  467.1249  28.50663
# 2        8    10   -5.457097  55.989938  343.4997  567.2656  29.64457
# 3        8  10.5   -3.174246  17.742429  298.8176  510.0382  30.07509
# 4        8    11    -3.36215 -14.486921  308.6841  562.1135   30.6643
# ...    ...   ...         ...        ...       ...       ...       ...
# 12695  365    22    1.317576  -2.113446 -4.222929 -1.650576  24.11463
# 12696  365  22.5    0.234337 -17.096266  1.974016 -2.103711  23.99404
# 12697  365    23   -0.224384 -10.566178 -5.732129 -2.074909  23.87093
# 12698  365  23.5    1.597789  -9.588491 -4.534221 -2.309459   23.6706
# 12699  365    24    1.426377   -5.17779 -6.128092 -1.824817  23.67208
#
#            Tsoil        rH        VPD     Ustar
# 0           degC         %        hPa      ms-1
# 1      28.717215  59.81609  15.396101  0.684502
# 2       29.11375  54.25453  18.724118  0.586166
# 3      29.542745  50.37691  20.822337   0.60327
# 4       29.96738  47.96687  22.586022  0.609596
# ...          ...       ...        ...       ...
# 12695   29.31614  84.10452   4.693953  0.341839
# 12696   29.22911  86.27364   4.024035  0.374856
# 12697   29.14392  87.43149   3.657315  0.360931
# 12698   29.05899  88.96199   3.173296  0.431153
# 12699   28.97242  89.76054   2.943986  0.366103
#
# [12700 rows x 11 columns]

# %%
df_withoutNaNandUnits = df_withoutNaN[1:-1]
df_withoutNaNandUnits
# Out:
#        Day  Hour       NEE         LE         H        Rg      Tair  \
# 1        8   9.5 -1.282251  19.633976  293.5131  467.1249  28.50663
# 2        8    10 -5.457097  55.989938  343.4997  567.2656  29.64457
# 3        8  10.5 -3.174246  17.742429  298.8176  510.0382  30.07509
# 4        8    11  -3.36215 -14.486921  308.6841  562.1135   30.6643
# 5        8  11.5 -3.737496   11.66765  383.1186  489.9342  31.03038
# ...    ...   ...       ...        ...       ...       ...       ...
# 12694  365  21.5  1.105137  19.396823  -5.08671 -2.153937  24.05438
# 12695  365    22  1.317576  -2.113446 -4.222929 -1.650576  24.11463
# 12696  365  22.5  0.234337 -17.096266  1.974016 -2.103711  23.99404
# 12697  365    23 -0.224384 -10.566178 -5.732129 -2.074909  23.87093
# 12698  365  23.5  1.597789  -9.588491 -4.534221 -2.309459   23.6706
#
#            Tsoil        rH        VPD     Ustar
# 1      28.717215  59.81609  15.396101  0.684502
# 2       29.11375  54.25453  18.724118  0.586166
# 3      29.542745  50.37691  20.822337   0.60327
# 4       29.96738  47.96687  22.586022  0.609596
# 5      30.376165  45.71235  24.064133  0.564155
# ...          ...       ...        ...       ...
# 12694   29.41369  81.65815   5.396727   0.37275
# 12695   29.31614  84.10452   4.693953  0.341839
# 12696   29.22911  86.27364   4.024035  0.374856
# 12697   29.14392  87.43149   3.657315  0.360931
# 12698   29.05899  88.96199   3.173296  0.431153
#
# [12698 rows x 11 columns]

# %%
df_withoutNaNandUnits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12698 entries, 1 to 12698
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Day     12698 non-null  object
#  1   Hour    12698 non-null  object
#  2   NEE     12698 non-null  object
#  3   LE      12698 non-null  object
#  4   H       12698 non-null  object
#  5   Rg      12698 non-null  object
#  6   Tair    12698 non-null  object
#  7   Tsoil   12698 non-null  object
#  8   rH      12698 non-null  object
#  9   VPD     12698 non-null  object
#  10  Ustar   12698 non-null  object
# dtypes: object(11)
# memory usage: 1.1+ MB

# %%
'''
Here we have a problem as the read_excel method imported data as objects, rather than floats or integers.
This issue disables the possibility of using mathematical methods to that dataframe.
'''
df_withoutNaNandUnits.isnull().sum()
# Out:
# Day      0
# Hour     0
# NEE      0
# LE       0
# H        0
# Rg       0
# Tair     0
# Tsoil    0
# rH       0
# VPD      0
# Ustar    0
# dtype: int64

# %%
'''
As can be seen here, the describe method doesnt report all the info because of having objects as data
Each column should be decoded into float or integer before going on.
'''
df_withoutNaNandUnits.describe()
# Out:
#           Day     Hour           NEE            LE           H            Rg  \
# count   12698  12698.0  12698.000000  12698.000000  12698.0000  12698.000000
# unique    315     48.0  12697.000000  12697.000000  12692.0000  12687.000000
# top       130     17.5      2.132852     98.859694    271.9746     -2.119701
# freq       48    289.0      2.000000      2.000000      2.0000      2.000000
#
#                Tair         Tsoil          rH      VPD         Ustar
# count   12698.00000  12698.000000  12698.0000  12698.0  12698.000000
# unique  12640.00000  12667.000000  12636.0000  12561.0  12687.000000
# top        30.53282     29.265335    100.0377      0.0      0.437753
# freq        2.00000      3.000000      6.0000    138.0      2.000000

# %%
'''
In case still there is any doubt...
'''
print(df_withoutNaNandUnits.dtypes)
# Out:
# Day      object
# Hour     object
# NEE      object
# LE       object
# H        object
# Rg       object
# Tair     object
# Tsoil    object
# rH       object
# VPD      object
# Ustar    object
# dtype: object

# %%
'''
We proceed with the conversion, column by column
'''
df_withoutNaNandUnits['Day']   = df_withoutNaNandUnits['Day'].astype(int)
df_withoutNaNandUnits['Hour']  = df_withoutNaNandUnits['Hour'].astype(float)
df_withoutNaNandUnits['NEE']   = df_withoutNaNandUnits['NEE'].astype(float)
df_withoutNaNandUnits['LE']    = df_withoutNaNandUnits['LE'].astype(float)
df_withoutNaNandUnits['H']     = df_withoutNaNandUnits['H'].astype(float)
df_withoutNaNandUnits['Rg']    = df_withoutNaNandUnits['Rg'].astype(float)
df_withoutNaNandUnits['Tair']  = df_withoutNaNandUnits['Tair'].astype(float)
df_withoutNaNandUnits['Tsoil'] = df_withoutNaNandUnits['Tsoil'].astype(float)
df_withoutNaNandUnits['rH']    = df_withoutNaNandUnits['rH'].astype(float)
df_withoutNaNandUnits['VPD']   = df_withoutNaNandUnits['VPD'].astype(float)
df_withoutNaNandUnits['Ustar'] = df_withoutNaNandUnits['Ustar'].astype(float)
df_withoutNaNandUnits
# Out:
# /tmp/ipykernel_24425/626383233.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_withoutNaNandUnits['Day']   = df_withoutNaNandUnits['Day'].astype(int)
# /tmp/ipykernel_24425/626383233.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_withoutNaNandUnits['Hour']  = df_withoutNaNandUnits['Hour'].astype(float)
# /tmp/ipykernel_24425/626383233.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_withoutNaNandUnits['NEE']   = df_withoutNaNandUnits['NEE'].astype(float)
# /tmp/ipykernel_24425/626383233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_withoutNaNandUnits['LE']    = df_withoutNaNandUnits['LE'].astype(float)
# /tmp/ipykernel_24425/626383233.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_withoutNaNandUnits['H']     = df_withoutNaNandUnits['H'].astype(float)
# /tmp/ipykernel_24425/626383233.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_withoutNaNandUnits['Rg']    = df_withoutNaNandUnits['Rg'].astype(float)
# /tmp/ipykernel_24425/626383233.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_withoutNaNandUnits['Tair']  = df_withoutNaNandUnits['Tair'].astype(float)
# /tmp/ipykernel_24425/626383233.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_withoutNaNandUnits['Tsoil'] = df_withoutNaNandUnits['Tsoil'].astype(float)
# /tmp/ipykernel_24425/626383233.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_withoutNaNandUnits['rH']    = df_withoutNaNandUnits['rH'].astype(float)
# /tmp/ipykernel_24425/626383233.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_withoutNaNandUnits['VPD']   = df_withoutNaNandUnits['VPD'].astype(float)
# /tmp/ipykernel_24425/626383233.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_withoutNaNandUnits['Ustar'] = df_withoutNaNandUnits['Ustar'].astype(float)
#        Day  Hour       NEE         LE           H          Rg      Tair  \
# 1        8   9.5 -1.282251  19.633976  293.513100  467.124900  28.50663
# 2        8  10.0 -5.457097  55.989938  343.499700  567.265600  29.64457
# 3        8  10.5 -3.174246  17.742429  298.817600  510.038200  30.07509
# 4        8  11.0 -3.362150 -14.486921  308.684100  562.113500  30.66430
# 5        8  11.5 -3.737496  11.667650  383.118600  489.934200  31.03038
# ...    ...   ...       ...        ...         ...         ...       ...
# 12694  365  21.5  1.105137  19.396823   -5.086710   -2.153937  24.05438
# 12695  365  22.0  1.317576  -2.113446   -4.222929   -1.650576  24.11463
# 12696  365  22.5  0.234337 -17.096266    1.974016   -2.103711  23.99404
# 12697  365  23.0 -0.224384 -10.566178   -5.732129   -2.074909  23.87093
# 12698  365  23.5  1.597789  -9.588491   -4.534221   -2.309459  23.67060
#
#            Tsoil        rH        VPD     Ustar
# 1      28.717215  59.81609  15.396101  0.684502
# 2      29.113750  54.25453  18.724118  0.586166
# 3      29.542745  50.37691  20.822337  0.603270
# 4      29.967380  47.96687  22.586022  0.609596
# 5      30.376165  45.71235  24.064133  0.564155
# ...          ...       ...        ...       ...
# 12694  29.413690  81.65815   5.396727  0.372750
# 12695  29.316140  84.10452   4.693953  0.341839
# 12696  29.229110  86.27364   4.024035  0.374856
# 12697  29.143920  87.43149   3.657315  0.360931
# 12698  29.058990  88.96199   3.173296  0.431153
#
# [12698 rows x 11 columns]

# %%
df_withoutNaNandUnits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12698 entries, 1 to 12698
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Day     12698 non-null  int64
#  1   Hour    12698 non-null  float64
#  2   NEE     12698 non-null  float64
#  3   LE      12698 non-null  float64
#  4   H       12698 non-null  float64
#  5   Rg      12698 non-null  float64
#  6   Tair    12698 non-null  float64
#  7   Tsoil   12698 non-null  float64
#  8   rH      12698 non-null  float64
#  9   VPD     12698 non-null  float64
#  10  Ustar   12698 non-null  float64
# dtypes: float64(10), int64(1)
# memory usage: 1.1 MB

# %%
'''
Now it goes
It seems to be no outliers
'''
df_withoutNaNandUnits.describe()
# Out:
#                 Day          Hour           NEE            LE             H  \
# count  12698.000000  12698.000000  12698.000000  12698.000000  12698.000000
# mean     177.619940     12.653016     -0.519348     21.203777     86.177114
# std      112.541575      6.859770      4.007970     40.248518    132.594249
# min        8.000000      0.500000    -14.975209    -49.953709    -46.526950
# 25%       76.000000      7.000000     -2.933721     -2.676834     -7.539441
# 50%      153.000000     13.000000      0.708028      5.482510      5.298768
# 75%      292.000000     18.500000      1.884775     30.710592    167.179000
# max      365.000000     24.000000      9.996666    199.862835    599.594100
#
#                  Rg          Tair         Tsoil            rH           VPD  \
# count  12698.000000  12698.000000  12698.000000  12698.000000  12698.000000
# mean     190.033540     26.723424     27.968602     72.729323     10.875000
# std      249.604016      3.480663      2.856498     18.860919      9.374398
# min       -4.238395     16.396480     21.610355     26.474730      0.000000
# 25%       -1.916214     23.968520     25.772622     56.861928      3.176921
# 50%       10.553825     26.088935     28.107300     77.431855      7.409081
# 75%      378.359900     29.399460     30.256099     89.144790     17.362999
# max      915.810200     36.873290     34.449420    100.058600     41.533249
#
#               Ustar
# count  12698.000000
# mean       0.419865
# std        0.175950
# min        0.000000
# 25%        0.295565
# 50%        0.422367
# 75%        0.552979
# max        1.002762

# %%
'''
To double check for outliers I display box plots
'''
#from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

fig, axs = plt.subplots(9,1,dpi=95, figsize=(7,17))
i = 0
for col in df_withoutNaNandUnits.columns:
    axs[i].boxplot(df_withoutNaNandUnits[col], vert=False)
    axs[i].set_ylabel(col)
    i+=1
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/borja/Documentos/PROJECTS/ArtificialNeuralNetworkForExtrapolatingData/ANN_for_gap_filling.ipynb Cell 12 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/home/borja/Documentos/PROJECTS/ArtificialNeuralNetworkForExtrapolatingData/ANN_for_gap_filling.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a> i = 0
#       <a href='vscode-notebook-cell:/home/borja/Documentos/PROJECTS/ArtificialNeuralNetworkForExtrapolatingData/ANN_for_gap_filling.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a> for col in df_withoutNaNandUnits.columns:
# ---> <a href='vscode-notebook-cell:/home/borja/Documentos/PROJECTS/ArtificialNeuralNetworkForExtrapolatingData/ANN_for_gap_filling.ipynb#X16sZmlsZQ%3D%3D?line=9'>10</a>     axs[i].boxplot(df_withoutNaNandUnits[col], vert=False)
#      <a href='vscode-notebook-cell:/home/borja/Documentos/PROJECTS/ArtificialNeuralNetworkForExtrapolatingData/ANN_for_gap_filling.ipynb#X16sZmlsZQ%3D%3D?line=10'>11</a>     axs[i].set_ylabel(col)
#      <a href='vscode-notebook-cell:/home/borja/Documentos/PROJECTS/ArtificialNeuralNetworkForExtrapolatingData/ANN_for_gap_filling.ipynb#X16sZmlsZQ%3D%3D?line=11'>12</a>     i+=1
#
# IndexError: index 9 is out of bounds for axis 0 with size 9
